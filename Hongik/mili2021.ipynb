# %% [markdown]
# <a href="https://colab.research.google.com/github/hyunwoo94/DataScience/blob/main/mili2021.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import csv

max_temp = -999 #최고 기온 값을 저장할 변수 --> 명확한 결과를 위해 극적인 값으로 셋팅
max_data =''  #최고 기온이 가장 높았던 날짜를 저장하는 변수



f = open('/content/mili.csv', 'r', encoding='cp949') # or encoding='euc-kr'

data = csv.reader(f)
header = next(data)  #헤더 추출

for row in data :
  #최고 기온 데이터가 ''(결측치) 확인
  if row[-1] == '':
    row[-1] = -999 # -999를 넣어서 빈 문자열('')이 있던 자리라고 표시
    
  row[-1] = float(row[-1])  #기온 데이터를 실수형으로 변환
 
 #최고 기온의 정보를 저장
  if max_temp < row[-1]:
    max_date = row[0]
    max_temp = row[-1]

f.close()

print('기상 관측 이래 동두천의 최고 기온이 가장 높았던 날은' , max_date+'로', max_temp,'도 였습니다.')
# Out:
# 기상 관측 이래 동두천의 최고 기온이 가장 높았던 날은 2018-08-01로 38.7 도 였습니다.

# %%
import csv

min_temp = 9999 #최저 기온 값을 저장할 변수 --> 명확한 결과를 위해 극적인 값으로 셋팅
min_data =''  #최저 기온이 가장 높았던 날짜를 저장하는 변수



f = open('/content/mili.csv', 'r', encoding='cp949') # or encoding='euc-kr'

data = csv.reader(f)
header = next(data)  #헤더 추출

for row in data :
  #최저 기온 데이터가 ''(결측치) 확인
  if row[-2] == '':
    row[-2] = 9999 # 9999를 넣어서 빈 문자열('')이 있던 자리라고 표시
    
  row[-2] = float(row[-2])  #기온 데이터를 실수형으로 변환
 
 #최저 기온의 정보를 저장
  if min_temp > row[-2]:
    min_date = row[0]
    min_temp = row[-2]

f.close()

print('기상 관측 이래 동두천의 최저 기온이 가장 낮았던 날은' , min_date+'로', min_temp,'도 였습니다.')
# Out:
# 기상 관측 이래 동두천의 최저 기온이 가장 낮았던 날은 2018-12-28로 -15.5 도 였습니다.

# %%
import csv
import matplotlib.pyplot as plt #1) 라이브러리 임포트


max_temp = [] #결측치를 제거한 최고 기온 리스트
min_temp = []

f = open('/content/mili.csv', 'r', encoding='cp949') # or encoding='euc-kr'

data = csv.reader(f)
header = next(data)  #헤더 추출


for row in data:
  if row[-1] != '' :   #최고 기온이 ''(빈문자열)이 아니면,
    max_temp.append(float(row[-1]))
result

f = open('/content/mili.csv', 'r', encoding='cp949') # or encoding='euc-kr'

data = csv.reader(f)
header = next(data)  #헤더 추출
for row in data:
  if row[-2] != '' :   #최고 기온이 ''(빈문자열)이 아니면,
    min_temp.append(float(row[-2]))
result

plt.figure(dpi=200)
#plt.figure(dpi=200)
plt.title("dongdocheon")
plt.plot(max_temp, 'r',label='Max')
plt.plot(min_temp, 'g',label='Min')
plt.legend(loc="upper right")
plt.xlabel("date")
x_range, y_range = plt.xlim(), plt.ylim()
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
import matplotlib.pyplot as plt #  1)라이브러리 임포트

plt.plot([1,2,3,4],[12,43,25,15]) # 2)plt.plot(x,y) 함수에 데이터 입력하기
plt.show() #그래프 보여주기

# %%
import csv
import matplotlib.pyplot as plt #1) 라이브러리 임포트


max_temp = [] #결측치를 제거한 최고 기온 리스트
min_temp = []

f = open('/content/mili.csv', 'r', encoding='cp949') # or encoding='euc-kr'

data = csv.reader(f)
header = next(data)  #헤더 추출


for row in data:
  if row[-1] != '' :   #최고 기온이 ''(빈문자열)이 아니면,
    max_temp.append(float(row[-1]))
result

f = open('/content/mili.csv', 'r', encoding='cp949') # or encoding='euc-kr'

data = csv.reader(f)
header = next(data)  #헤더 추출
for row in data:
  if row[-2] != '' :   #최고 기온이 ''(빈문자열)이 아니면,
    min_temp.append(float(row[-2]))
result

plt.figure(dpi=200)
#plt.figure(dpi=200)
plt.plot(max_temp, 'r',label='Max')
plt.plot(min_temp, 'g',label='Min')
plt.legend(loc="upper right")
plt.show
----------------




plt.axis('scaled')


plt.plot([1, 2, 3, 4], [2, 3, 5, 10])

x_range, y_range = plt.xlim(), plt.ylim()
print(x_range, y_range)

axis_range = plt.axis('scaled')
print(axis_range)

plt.show()
# Out:
#   File "<ipython-input-41-586044c7544b>", line 36
#     ----------------
#                     ^
# SyntaxError: invalid syntax
