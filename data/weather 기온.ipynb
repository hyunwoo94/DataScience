# %% [markdown]
# `step 1) 데이터 불러서 한 행씩 출력하기

# %%
import csv

f = open('/content/seoul.csv', 'r', encoding='cp949') # or encoding='euc-kr'

data = csv.reader(f)
header = next(data)  #헤더 추출

for row in data:
  print(row)
  #최고기온 데이터만 추출 --> 오류발생  -->결측지 때문에 ---> 어떻게 처리할까?
  row[-1] = float(row[-1])
  #float(row[-1])  #   float(row[4]) --> 제일 마지막 컬럼  -> -1로 인덱스 처리


f.close()
# 오류나는거 확인 셀
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# ['1936-12-24', '108', '-1.1', '-5.7', '3.5']
# ['1936-12-25', '108', '1.1', '-2.9', '6.3']
# ['1936-12-26', '108', '1.1', '-2.1', '4.7']
# ['1936-12-27', '108', '-0.8', '-3.7', '2.3']
# ['1936-12-28', '108', '0.3', '-5.7', '5.4']
# ['1936-12-29', '108', '0', '-5.6', '5.6']
# ['1936-12-30', '108', '-0.3', '-5.5', '3.9']
# ['1936-12-31', '108', '1.8', '-3', '5.7']
# ['1937-01-01', '108', '-1.3', '-3.3', '3.7']
# ['1937-01-02', '108', '-2.3', '-8.2', '3']
# ['1937-01-03', '108', '-0.3', '-6.7', '7.8']
# ['1937-01-04', '108', '3', '-5.3', '9.8']
# ['1937-01-05', '108', '3.3', '0.9', '6.3']
# ['1937-01-06', '108', '-1.6', '-3.4', '2.4']
# ['1937-01-07', '108', '-5', '-8', '-1.8']
# ['1937-01-08', '108', '-4.4', '-9.3', '0.3']
# ['1937-01-09', '108', '-4.8', '-9.4', '-0.2']
# ['1937-01-10', '108', '-9.6', '-12.9', '-5.9']
# ['1937-01-11', '108', '-10.8', '-13.2', '-7.5']
# ['1937-01-12', '108', '-9', '-12.9', '-5.1']
# ...

# %% [markdown]
# step 2) 데이터 중 최고기온을  실수로 변환하여 한 행씩 출력하기

# %%
import csv

max_temp = -999 #최고 기온 값을 저장할 변수 --> 명확한 결과를 위해 극적인 값으로 셋팅
max_data =''  #최고 기온이 가장 높았던 날짜를 저장하는 변수



f = open('/content/seoul.csv', 'r', encoding='cp949') # or encoding='euc-kr'

data = csv.reader(f)
header = next(data)  #헤더 추출

for row in data :
  #최고 기온 데이터가 ''(결측치) 확인
  if row[-1] == '':
    row[-1] = -999 # -999를 넣어서 빈 문자열('')이 있던 자리라고 표시
    
  row[-1] = float(row[-1])  #기온 데이터를 실수형으로 변환
  print(row[0],row[-1]) #날짜 데이터와 같이 출력 
f.close()

# %% [markdown]
# step 3) 최고 기온과 최고 기온이었던 날짜 찾기

# %%
import csv

max_temp = -999 #최고 기온 값을 저장할 변수 --> 명확한 결과를 위해 극적인 값으로 셋팅
max_data =''  #최고 기온이 가장 높았던 날짜를 저장하는 변수



f = open('/content/seoul.csv', 'r', encoding='cp949') # or encoding='euc-kr'

data = csv.reader(f)
header = next(data)  #헤더 추출

for row in data :
  #최고 기온 데이터가 ''(결측치) 확인
  if row[-1] == '':
    row[-1] = -999 # -999를 넣어서 빈 문자열('')이 있던 자리라고 표시
    
  row[-1] = float(row[-1])  #기온 데이터를 실수형으로 변환
 
 #최고 기온의 정보를 저장
  if max_temp < row[-1]:
    max_date = row[0]
    max_temp = row[-1]

f.close()

print('기상 관측 이래 서울의 최고 기온이 가장 높았던 날은' , max_date+'로', max_temp,'도 였습니다.')
# Out:
# 기상 관측 이래 서울의 최고 기온이 가장 높았던 날은 2018-08-01로 39.6 도 였습니다.

# %% [markdown]
# step 4) 최저 기온과 최저 기온이었던 날짜 찾기(스스로 해보기)[링크 텍스트](https://)

# %%
import csv

min_temp = 9999 #최저 기온 값을 저장할 변수 --> 명확한 결과를 위해 극적인 값으로 셋팅
min_data =''  #최저 기온이 가장 높았던 날짜를 저장하는 변수



f = open('/content/seoul.csv', 'r', encoding='cp949') # or encoding='euc-kr'

data = csv.reader(f)
header = next(data)  #헤더 추출

for row in data :
  #최저 기온 데이터가 ''(결측치) 확인
  if row[-2] == '':
    row[-2] = 9999 # 9999를 넣어서 빈 문자열('')이 있던 자리라고 표시
    
  row[-2] = float(row[-2])  #기온 데이터를 실수형으로 변환
 
 #최저 기온의 정보를 저장
  if min_temp > row[-2]:
    min_date = row[0]
    min_temp = row[-2]

f.close()

print('기상 관측 이래 서울의 최저 기온이 가장 낮았던 날은' , min_date+'로', min_temp,'도 였습니다.')
# Out:
# 기상 관측 이래 서울의 최저 기온이 가장 낮았던 날은 1927-12-31로 -23.1 도 였습니다.

# %%
import csv
import matplotlib.pyplot as plt #1) 라이브러리 임포트

f = open('/content/seoul.csv', 'r', encoding='cp949') # or encoding='euc-kr'

data = csv.reader(f)
header = next(data)  #헤더 추출

result = [] #결측치를 제거한 최고 기온 리스트

for row in data:
  if row[-1] != '' :   #최고 기온이 ''(빈문자열)이 아니면,
    result.append(float(row[-1]))
result

plt.figure(figsize=(10,2), dpi=200)
#plt.figure(dpi=200)
plt.plot(result, 'r')
plt.show
