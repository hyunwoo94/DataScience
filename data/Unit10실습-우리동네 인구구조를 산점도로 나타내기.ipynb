# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
 
# %config InlineBackend.figure_format = 'retina'
 
# !apt -qq -y install fonts-nanum
 
import matplotlib.font_manager as fm

fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
font = fm.FontProperties(fname=fontpath, size=9)
plt.rc('font', family='NanumBarunGothic') 
mpl.font_manager._rebuild()
# Out:
# fonts-nanum is already the newest version (20170925-1).
# 0 upgraded, 0 newly installed, 0 to remove and 39 not upgraded.

# %%
import matplotlib.pyplot as plt
import csv
f= open('gender.csv',encoding='cp949')
data =csv.reader(f)
result_incheon=[] #남여 차이 비율 퍼센트 담을 리스트
name = input('인구 구조가 알고 싶은 지역을 입력해 주세요 : ')
name_incheon='인천광역시'
for row in data:
  if name in row[0]:
    for i in range(3,104) :
      result_incheon.append((int(row[i].replace(',',''))-int(row[i+103].replace(',','')))/(int(row[i].replace(',',''))+int(row[i+103].replace(',',''))))
    break
result_incheon=[i*100 for i in result_busan]
f.close()
plt. figure(dpi = 200)
plt.style.use('ggplot') 
plt.rc('font', family='NanumBarunGothic') 
plt.rcParams['axes.unicode_minus'] = False
# 꺾은선 그래프로 남여 인구수 데이터 표현하기
plt.title(name + '지역의 남녀 성별 인구 차이')
plt.bar(range(101), result)
plt.show()
# Out:
# 인구 구조가 알고 싶은 지역을 입력해 주세요 : 경기도
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-e3c7ee0f8853> in <module>()
#      19 # 꺾은선 그래프로 남여 인구수 데이터 표현하기
#      20 plt.title(name + '지역의 남녀 성별 인구 차이')
# ---> 21 plt.bar(range(101), result)
#      22 plt.show()
#
# NameError: name 'result' is not defined
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44221 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44592 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46020 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
import matplotlib.pyplot as plt
import csv
f= open('gender.csv',encoding='cp949')
data =csv.reader(f)
result_busan=[] #남여 차이 비율 퍼센트 담을 리스트
name_busan='부산광역시'
for row in data:
  if name in row[0]:
    for i in range(3,104) :
      result_busan.append((int(row[i].replace(',',''))-int(row[i+103].replace(',','')))/(int(row[i].replace(',',''))+int(row[i+103].replace(',',''))))
    break
result_busan=[i*100 for i in result_busan]
f.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-e657e6ac39ca> in <module>()
#       6 name_busan='부산광역시'
#       7 for row in data:
# ----> 8   if name in row[0]:
#       9     for i in range(3,104) :
#      10       result_busan.append((int(row[i].replace(',',''))-int(row[i+103].replace(',','')))/(int(row[i].replace(',',''))+int(row[i+103].replace(',',''))))
#
# NameError: name 'name' is not defined
